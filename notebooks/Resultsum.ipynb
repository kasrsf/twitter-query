# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np 
import re

from sklearn.metrics import precision_recall_curve, mutual_info_score, normalized_mutual_info_score

from pyspark.ml.feature import HashingTF, Tokenizer, IDF, StopWordsRemover, CountVectorizer, VectorAssembler
from pyspark.sql import functions as F
from pyspark.sql.functions import explode, lit, col, when, lower

import matplotlib.pyplot as plt

from hashtag_dict import topic_dict

from Evaluation import *
from FeatureExtraction import *
from Filter import *
from TestFramework import *
from LPFormulations import *
from CoverageCalculator import *

# %% [markdown]
# # Review Previous Work

# %%
class API:
    def __init__(self, directory, frac=1, seed=123):
        if frac < 1:
            self.data = spark.read.parquet(directory).sample(False, frac, seed)
        else:
            self.data = spark.read.parquet(directory)
          
    def get_raw_data(self):
         return self.data

    def get_filtered_data(self, terms=[], hashtags=None, users=None, locs=None, mentions=None):   
        return filter_data(self.data, terms, hashtags, users, locs, mentions)
    
    
class DataPreprocessor():
    def __init__(self, data, topic, load_labled=False, filter_empty_hashtags=False):
        if filter_empty_hashtags == True:
            self.data = data.filter(col("hashtag") != "empty_hashtag")
        else:
            self.data = data

        if load_labled == True:
            labled_dir = "/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/labeled_data/" + topic
            pos_dir = labled_dir + "/pos"
            topical_tweet_ids = spark.read.parquet(pos_dir)
            topical_tweets = topical_tweet_ids.join(self.data, "tweet_id").withColumn("label", lit(1))
            
            neg_dir = labled_dir + "/neg"
            non_topical_tweet_ids = spark.read.parquet(neg_dir)#.sample(False, 0.1, 123)
            non_topical_tweets = non_topical_tweet_ids.join(self.data, "tweet_id").withColumn("label", lit(0))

            self.labled_data = topical_tweets.union(non_topical_tweets)
        else:
            self.labled_data = None

        tokenizer = Tokenizer(inputCol="hashtag", outputCol="each_hashtag")
        hashtags_df = tokenizer.transform(self.data)

        hashtag = hashtags_df.select("tweet_id","create_time","each_hashtag")
        self.hash_exploded = hashtag.withColumn('each_hashtag', explode('each_hashtag'))
    
    def get_labled_data(self, topic):
        if self.labled_data == None:
            topic_lables = topic_dict[topic]

            topical_ids = self.hash_exploded.select(self.hash_exploded.tweet_id)\
                                                    .where(self.hash_exploded.each_hashtag\
                                                            .isin(topic_lables))\
                                                    .distinct().cache()

            labled_topical = topical_ids.withColumn("topical", lit(1))
            self.labled_data = self.data.join(labled_topical, self.data.tweet_id == labled_topical.tweet_id, "left")\
                                                      .select(self.data.create_time,\
                                                             self.data.from_id,\
                                                             self.data.from_user,\
                                                             self.data.hashtag,\
                                                             self.data.location,\
                                                             self.data.mention,\
                                                             self.data.tweet_id,\
                                                             self.data.term,\
                                                              F.when(labled_topical.topical == 1, 1.0)\
                                                                .otherwise(0.0).alias("label"))
        return self.labled_data
    
    def get_num_of_positvies(self):
        if self.labled_data == None:
            return 0
        
        return self.labled_data.where(col("label") == 1.0).count()
    
    def get_data_size(self):
        if self.labled_data == None:
            return 0
        
        return self.labled_data.count()
        
    def temporal_split(self, topic, balance_data=True, seed=0, remove_topic_hashtags=False, ch=False):
        topic_lables = topic_dict[topic]
        labled_data = self.get_labled_data(topic)
        tweet_labels = labled_data.select("tweet_id", "label")
        
        df_birthday = self.hash_exploded.join(tweet_labels,\
                                 self.hash_exploded.tweet_id == tweet_labels.tweet_id,\
                                 "inner").select(self.hash_exploded.create_time,\
                                                 self.hash_exploded.each_hashtag,\
                                                 self.hash_exploded.tweet_id)
        
        ## Find out the "birthday", or the earliest appearing time of each hashtag. 
        ## (add an extra column of 1 to mark as topical, will be used in a join later)
        ordered_hashtag_set = df_birthday.\
                              groupby("each_hashtag").\
                              agg({"create_time": "min"}).\
                              orderBy('min(create_time)', ascending=True).\
                              withColumnRenamed("min(create_time)", "birthday").\
                              where(df_birthday.each_hashtag.isin(topic_lables)).cache()
                            
        time_span = ordered_hashtag_set.count()

        train_valid_split_time = np.floor(np.multiply(time_span, 0.75)).astype(int)
        valid_test_split_time = np.floor(np.multiply(time_span, 0.85)).astype(int)

        # Converting to Pandas for random row access.
        pd_ordered_hashtag_set = ordered_hashtag_set.toPandas()
        
        # locate the timestamp of the cutoff point. Will be used later to split Dataframe.
        train_valid_time = pd_ordered_hashtag_set.iloc[train_valid_split_time]['birthday']
        valid_test_time = pd_ordered_hashtag_set.iloc[valid_test_split_time]['birthday']
    
        training_set = labled_data.where(col("create_time") <= train_valid_time)
        validation_set = labled_data.where((col("create_time") > train_valid_time) \
                                           & (col("create_time") <= valid_test_time))
        test_set = labled_data.where(col("create_time") > valid_test_time)
        
        if remove_topic_hashtags == True:
            train_hashtags = pd_ordered_hashtag_set[:train_valid_split_time]['each_hashtag'].tolist()
            valid_hashtags = pd_ordered_hashtag_set[train_valid_split_time:valid_test_split_time]['each_hashtag']\
                                .tolist()
            test_hashtags = pd_ordered_hashtag_set[valid_test_split_time:]['each_hashtag'].tolist()
            
            valid_test_hashtags = valid_hashtags + test_hashtags
            hashtags_filter = [re.sub(r'(.*)', r'\\b\1\\b', hashtag) for hashtag in valid_test_hashtags]
            valid_test_hashtags_regex = '|'.join(hashtags_filter)
            if ch == True:
                invalid_train_ids = (training_set.filter(lower(training_set['hashtag']).rlike(valid_test_hashtags_regex)))\
                                        .select("tweet_id").distinct().rdd.flatMap(lambda x: x).collect()
            else:
                invalid_train_ids = (training_set.filter(training_set['hashtag'].rlike(valid_test_hashtags_regex)))\
                                        .select("tweet_id").distinct().rdd.flatMap(lambda x: x).collect()                
            training_set = training_set.where(~col("tweet_id").isin(invalid_train_ids)) 

            train_test_hashtags = train_hashtags + test_hashtags
            hashtags_filter = [re.sub(r'(.*)', r'\\b\1\\b', hashtag) for hashtag in train_test_hashtags]
            train_test_hashtags_regex = '|'.join(hashtags_filter)
            if ch == True:
                invalid_validation_ids = (validation_set.filter(lower(validation_set['hashtag']).rlike(train_test_hashtags_regex)))\
                                        .select("tweet_id").distinct().rdd.flatMap(lambda x: x).collect()
            else:
                invalid_validation_ids = (validation_set.filter(validation_set['hashtag'].rlike(train_test_hashtags_regex)))\
                                        .select("tweet_id").distinct().rdd.flatMap(lambda x: x).collect()

                
            print("Invalid Validation:" + str(len(invalid_validation_ids)))
            validation_set = validation_set.where(~col("tweet_id").isin(invalid_validation_ids))
            
            train_valid_hashtags = train_hashtags + valid_hashtags
            train_valid_hashtags_filter = [re.sub(r'(.*)', r'\\b\1\\b', hashtag) for hashtag in train_valid_hashtags]
            train_valid_hashtags_regex = '|'.join(train_valid_hashtags_filter)
            if ch == True:
                invalid_test_ids = (test_set.filter(lower(test_set['hashtag']).rlike(train_valid_hashtags_regex)))\
                                        .select("tweet_id").distinct().rdd.flatMap(lambda x: x).collect()
            else:
                invalid_test_ids = (test_set.filter(test_set['hashtag'].rlike(train_test_hashtags_regex)))\
                                        .select("tweet_id").distinct().rdd.flatMap(lambda x: x).collect()

                
            print("Invalid Test:" + str(len(invalid_test_ids)))
                
            test_set = test_set.where(~col("tweet_id").isin(invalid_test_ids))
        
        if balance_data == True:
            train_pos_count = training_set.where(col("label") == 1).count()
            train_neg_count = training_set.where(col("label") == 0).count()
            train_pos_neg_ratio = float(train_pos_count) / train_neg_count
            
            training_set_balanced = training_set.sampleBy("label", fractions={0: 2*train_pos_neg_ratio, 1: 1}, seed=seed)
            
            valid_pos_count = validation_set.where(col("label") == 1).count()
            valid_neg_count = validation_set.count() - valid_pos_count
            valid_pos_neg_ratio = float(valid_pos_count) / valid_neg_count
            
            validation_set_balanced = validation_set.sampleBy("label", fractions={0.0: valid_pos_neg_ratio, 1.0: 1}, seed=seed)
            
            return training_set, training_set_balanced, validation_set, validation_set_balanced, test_set
            
        return training_set, validation_set, test_set

# %% [markdown]
# # Natural Disaster Tweets in US

# %%
directory = "/mnt/66e695cd-1a0c-4e3b-9a50-55e01b788529/Training_data/Staging_final/"
api = API(directory)
raw_data = api.get_raw_data()

dp = DataPreprocessor(raw_data, "Natr_Disaster", load_labled=True, filter_empty_hashtags=True)

# %%
labled_data = dp.get_labled_data("Natr_Disaster")

# %%
labled_data#show(10)
# Out:
# [('tweet_id', 'string'),
#  ('create_time', 'double'),
#  ('from_id', 'string'),
#  ('from_user', 'string'),
#  ('hashtag', 'string'),
#  ('location', 'string'),
#  ('mention', 'string'),
#  ('term', 'string'),
#  ('label', 'int')]

# %%
users = pd.read_csv('users.txt', sep=" ", header=None)
user_list = users.values.tolist()
users = [u[0] for u in user_list]

# %%
natr_disaster_tweets = labled_data.filter(col("label") == 1)

# %%
natr_disaster_tweets_pd = natr_disaster_tweets.toPandas()

# %%
len(natr_disaster_tweets_pd)
# Out:
# 89440

# %%
natr_disaster_tweets_pd
# Out:
# tweet_id        object
# create_time    float64
# from_id         object
# from_user       object
# hashtag         object
# location        object
# mention         object
# term            object
# label            int64
# dtype: object

# %%
natr_disaster_tweets_us = natr_disaster_tweets_pd.loc[natr_disaster_tweets_pd['from_user'].str.lower().isin(users)]

# %%
natr_disaster_tweets_us
# Out:
#                  tweet_id   create_time     from_id        from_user  \
# 4      343103567302914048  1.370652e+09    31172792         cfdshark
# 9      344105385210294272  1.370890e+09   935451420   SandyUpdatesNY
# 10     317440764449808384  1.364533e+09   157597434       SHOUtime21
# 12     317448620343431168  1.364535e+09   494254456        salcamaro
# 16     410543672288350209  1.386734e+09   297428826    FirstNightArt
# 26     366029121278582784  1.376118e+09  1170711727   KirstinNoel722
# 27     372078318461276161  1.377560e+09   110753128           86Cane
# 29     505607979308032000  1.409396e+09    19850176  sandrasantander
# 36     485317857509904385  1.404558e+09  1394917244           NWSOPC
# 42     405101239891136512  1.385437e+09   112895255         tina5925
# 45     491790335509422081  1.406101e+09  2653486262         DaisaGee
# 89436  397521218192285696  1.383629e+09   126096057    KylieSabraArt
#
#                                                  hashtag  \
# 4       tropicalstorm humor charlestonsc hurricaneseason
# 9                                               NJ Sandy
# 10                                       TheU Hurricanes
# 12        hurricane tropicaldepression tmltalk goleafsgo
# 16                   Giants Abstract Painting Storm Fire
# 26                    PrayForWaynesville Flood Volunteer
# 27                                      Miami Hurricanes
# 29                                         earthquake CA
# 36                                          MODIS Arthur
# 42                                            Haiyan ani
# 45              TyphoonHenry Typhoon Henry Tropical stor
# 46                   mothernature lightning storm clouds
# 47     Winter Storm GulfCoast Southeast knowb4 safety...
# 49                                            Hurricanes
# 76                                     Gonzalo hurricane
# 80                                           Tornado ATL
# 98                                 PrayForThePhilippines
# 102                                        TyphoonHaiyan
# 109                                            hurricane
# 127                                        KashmirFloods
# 143                    GivingTuesday Haiyan LifewayGives
# 153                                               Haiyan
# 162            stormtroopers PepperOhana HurricaneIselle
# 167                                              tornado
# 170               Derry NorthernIreland Oklahoma Tornado
# 189                                        HurricaneWeek
# 197    noboysallowed skottieyoung jubilee kittypryde ...
# 235    RETWEET TeamFollowBack TeamAutoFollow PrayForT...
# 264       PleaseHelpThePHILIPPINES PrayForThePhilippines
# 278                                PrayForThePhilippines
# ...                                                  ...
# 89267                              Tornado ILWX HighRisk
# 89269                            Washington tornado ilwx
# 89270                                     Peoria Tornado
# 89271                                            tornado
# 89272                                       ilwx Tornado
# 89273                                       ilwx tornado
# 89275                                     Peoria tornado
# 89276                                            tornado
# 89277                              PrayForThePhilippines
# 89279                                            tornado
# 89283                             severe weather tornado
# 89287                                ilwx tornado damage
# 89293                                   Rachel hurricane
# 89297                                            tornado
# 89299                                            tornado
# 89300                                            tornado
# 89303                                            tornado
# 89306                                            Tornado
# 89314                                            tornado
# 89321                                 earthquake Tsunami
# 89323                          ukweather southeast storm
# 89331                                         hurricanes
# 89351                          themblankets floodwarning
# 89367                                     storm DC MD VA
# 89382                                         earthquake
# 89385                                             Haiyan
# 89391                 storm carrollcounty clouds rain wx
# 89396                       XMen Wolverine storm cyclops
# 89430                          ontimetraffic roads flood
# 89436                                Art Storm barn farm
#
#                              location  \
# 4                   loc_charleston_sc
# 9                        loc_new_york
# 10                 loc_fremont__la_ca
# 12                        loc_markham
# 16                         loc_london
# 26                 loc_springfield_mo
# 27                        loc_florida
# 29         loc_los_angeles_california
# 36                loc_college_park_md
# 42                  loc_manhattan_nyc
# 45                        loc_seattle
# 46                       loc_illinois
# 47     loc_norfolk_near_the_chesp_bay
# 49      loc_nyc_fl_and_on_your_screen
# 76               loc_san_diego_ca_usa
# 80              loc_florida_panhandle
# 98                    loc_richland_wa
# 102           loc_whittier_california
# 109                    empty_location
# 127                      loc_paradise
# 143                loc_los_angeles_ca
# 153        loc_san_francisco_bay_area
# 162                loc_honoluluhawaii
# 167                 loc_new_york_city
# 170        loc_derry_northern_ireland
# 189                       loc_atlanta
# 197              loc_san_francisco_ca
# 235                    empty_location
# 264                      loc_paradise
# 278                            loc_la
# ...                               ...
# 89267                  loc_norwich_ct
# 89269                   loc_olathe_ks
# 89270             loc_monticello_iowa
# 89271                loc_bradenton_fl
# 89272                loc_lake_mary_fl
# 89273             loc_northern_tundra
# 89275              loc_spartanburg_sc
# 89276            loc_warner_robins_ga
# 89277   loc_catch_me_in_the_milky_way
# 89279               loc_washington_dc
# 89283                     loc_indiana
# 89287         loc_tallahassee_florida
# 89293            loc_san_francisco_ca
# 89297                    loc_nebraska
# 89299                     loc_florida
# 89300                  loc_lincoln_ne
# 89303       loc_adams_county_nebraska
# 89306           loc_channelview_texas
# 89314              loc_omaha_nebraska
# 89321                 loc_new_orleans
# 89323            loc_london_greenwich
# 89331                  loc_raleigh_nc
# 89351                   loc_tupelo_ms
# 89367                    loc_tampa_fl
# 89382         loc_san_jose_california
# 89385                      loc_dayton
# 89391       loc_union_bridge_maryland
# 89396                     loc_oleanny
# 89430                loc_asheville_nc
# 89436                  loc_seattle_wa
#
#                                                  mention  \
# 4                                          empty_mention
# 9                                          OccupySandyNJ
# 10                                         empty_mention
# 12                                     MapleLeafs JLupul
# 16                                        ZeanaRomanovna
# 26                                         empty_mention
# 27                                         Manny_Navarro
# 29                                              quakesLA
# 36                                         empty_mention
# 42                                                  wspa
# 45                                              barbjonn
# 46                                         empty_mention
# 47                                            WeatherBug
# 49                                               YouTube
# 76                                       stormchaser4850
# 80                                        weatherchannel
# 98                                               TwainLe
# 102                                         OxfamAmerica
# 109                                        empty_mention
# 127                                             _Durdana
# 143                CharityMiles WFP wwpinc lifeway_kefir
# 153                                                  ABC
# 162                                           pepperlive
# 167                                        empty_mention
# 170                                        empty_mention
# 189                                        empty_mention
# 197                                        empty_mention
# 235                          Cjquidetlabad Cjquidetlabad
# 264                                           Godstagram
# 278                                         MrsCalum5SOS
# ...                                                  ...
# 89267                           wxBender SchuermanWxWHAG
# 89269                                            wxstorm
# 89270                                      Kid67y wxbrad
# 89271                                       ERICSORENSEN
# 89272  thestormreport ALStormChaser anthonywx Jack_La...
# 89273                                       BTSullivan91
# 89275                                       BTSullivan91
# 89276                                      reedtimmerTVN
# 89277                                     LaurenJauregui
# 89279                                      itsalleternal
# 89283                         ECTServicesKY JudeRedfield
# 89287                                       BTSullivan91
# 89293                                      empty_mention
# 89297                                        TWCBreaking
# 89299                       reedtimmerTVN FoxMariaMolina
# 89300            TWCBreaking RyanQMahoney weatherchannel
# 89303            TWCBreaking RyanQMahoney weatherchannel
# 89306                                      empty_mention
# 89314                                        TWCBreaking
# 89321                                     weatherchannel
# 89323                                      empty_mention
# 89331                                      empty_mention
# 89351                                      empty_mention
# 89367                               wusa9 hbwx ericagrow
# 89382                                    WheresItShaking
# 89385                             DaniNierenberg FAOnews
# 89391                                      empty_mention
# 89396                                      empty_mention
# 89430                                      LBRIGMAN_WLOS
# 89436                                      empty_mention
#
#                                                     term  label
# 4                                               hahahaha      1
# 9      rt two state hotlines established for elevatio...      1
# 10             clank clank clank clank clank clank clank      1
# 12     thats right folks turn that into a what a goal by      1
# 16                                    rt between two and      1
# 26     spending one of my days off going home to help...      1
# 27     rt video golden donofrio coley kehoe green and...      1
# 29     rt 243 magnitude 13 mi from tehachapi united s...      1
# 36     rgb airmass product shows losing tropical char...      1
# 42     rt our disaster teamsdr ian dacreis featured i...      1
# 45     rt tropical storm enters par codenamed henry t...      1
# 46     lightning show just above the clouds out here ...      1
# 47                                       rt rocks amp us      1
# 49     i didnt need a 1000 pound bike its a hard ride...      1
# 76     rt update forecast to become possibly the stro...      1
# 80     rt just in watch until 7am edt 6am cdt parts o...      1
# 98                                                    rt      1
# 102                 send a donation to to help survivors      1
# 109                shes all lightening and wind and rain      1
# 127    rt update call this number for rescue in rajba...      1
# 143    starting early i ran 2018 4 s relief amp thx2 ...      1
# 153    3 things to do before donating to typhoon reli...      1
# 162                           praying for the big island      1
# 167    pic teacher hugs child briarwood elementary af...      1
# 170    do you know of anyone locally living in or who...      1
# 189    watching our sizzle reel of past hurricane cov...      1
# 197                                          courtesy of      1
# 235                                rt for 1000 followers      1
# 264           rt make a change be good help other people      1
# 278    rt world wide donations water canned food rice...      1
# ...                                                  ...    ...
# 89267  rt mt from weektv in peoria il complete destru...      1
# 89269  rt unbelievable destruction coming out of il l...      1
# 89270                        rt credit to anthony khoury      1
# 89271  heads up ne illinoisnw indiana rt photo of app...      1
# 89272  rt mt rt more damage from pekin il rt just hit...      1
# 89273  good lord mt horrid pictures from near washing...      1
# 89275    rt photo via anthony khoury from earlier of the      1
# 89276  rt two dangerous warned supercells in the cham...      1
# 89277  rt if you havent already please please donate ...      1
# 89279  rt washington il is gone houses flattened pray...      1
# 89283                                rt great safety tip      1
# 89287  rt horrid pictures from near washingtonpeoria ...      1
# 89293  dr masters says tropical atlantic uneventful t...      1
# 89297  rt at 502p a confirmed was 1 mile w and 1 mile...      1
# 89299  rt first as it was developing se of york ne ta...      1
# 89300  rt one of first towns hit today rt sutton ne h...      1
# 89303  rt one of first towns hit today rt sutton ne h...      1
# 89306  643p et warning includes springfield oh storm ...      1
# 89314  rt at 541p spotters reported rainwrapped cone ...      1
# 89321  rt breaking magnitude68 struck off the coast o...      1
# 89323            to drive in the monsoon or not to drive      1
# 89331                                    well win friday      1
# 89351                   2017 f on a 38yrd game ending fg      1
# 89367  storm updates for dc area rt make sure to foll...      1
# 89382                            rt m 25 southern alaska      1
# 89385  rt farmers hit by typhoon need urgent assistan...      1
# 89391         some pictures from the storm earlier today      1
# 89396                                    watching xmen 2      1
# 89430  rt traffic continuing the update on road closu...      1
# 89436                           by kylie before the udtd      1
#
# [15541 rows x 9 columns]

# %%
natr_disaster_tweets_us.to_csv('natdis_us.csv', encoding='UTF-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-11-12dd18101398> in <module>()
# ----> 1 natr_disaster_tweets_us.to_csv('natdis_us.csv', index=False)
#
# /usr/lib64/python2.7/site-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1381                                      doublequote=doublequote,
#    1382                                      escapechar=escapechar, decimal=decimal)
# -> 1383         formatter.save()
#    1384
#    1385         if path_or_buf is None:
#
# /usr/lib64/python2.7/site-packages/pandas/formats/format.pyc in save(self)
#    1473                 self.writer = csv.writer(f, **writer_kwargs)
#    1474
# -> 1475             self._save()
#    1476
#    1477         finally:
#
# /usr/lib64/python2.7/site-packages/pandas/formats/format.pyc in _save(self)
#    1574                 break
#    1575
# -> 1576             self._save_chunk(start_i, end_i)
#    1577
#    1578     def _save_chunk(self, start_i, end_i):
#
# /usr/lib64/python2.7/site-packages/pandas/formats/format.pyc in _save_chunk(self, start_i, end_i)
#    1600                                         quoting=self.quoting)
#    1601
# -> 1602         lib.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#    1603
#    1604 # from collections import namedtuple
#
# pandas/lib.pyx in pandas.lib.write_csv_rows (pandas/lib.c:21075)()
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 4-9: ordinal not in range(128)

# %%
n = pd.read_csv("natdis_us_neg.csv", dtype={'tweet_id': str})

# %%
p.tweet_id
# Out:
# 0        343103567302914048
# 1        344105385210294272
# 2        317440764449808384
# 3        317448620343431168
# 4        410543672288350209
# 5        366029121278582784
# 6        372078318461276161
# 7        505607979308032000
# 8        485317857509904385
# 9        405101239891136512
# 10       491790335509422081
# 11       491791421800599554
# 12       428301499769569280
# 13       335841029280366592
# 14       521862354339123200
# 15       521870520628019200
# 16       399633192862228480
# 17       406640952116129792
# 18       527715916604530689
# 19       508553035010670592
# 20       401133096965128192
# 21       401136313975332864
# 22       497155760493559809
# 23       336773800534347777
# 24       336779290886668289
# 25       364479896367546368
# 26       380976672801308672
# 27       400556325618589696
# 28       400561908257787904
# 29       400563233628516352
#                 ...
# 15511    402149427135385600
# 15512    402149817196883968
# 15513    402149884335120384
# 15514    402150232449765376
# 15515    402150572167401473
# 15516    402150727365042176
# 15517    402150979023671296
# 15518    402151742399598592
# 15519    402151784333852672
# 15520    402151943717797888
# 15521    402152270877306880
# 15522    402152702890999808
# 15523    515883160056246273
# 15524    465618272805998592
# 15525    465621485638647809
# 15526    465621829550231552
# 15527    465622869766983680
# 15528    465623666693115904
# 15529    465625168216596480
# 15530    487701027500855297
# 15531    418395807814254592
# 15532    428556807083003905
# 15533    401547875856809984
# 15534    345159711596875776
# 15535    397688319267442688
# 15536    403553134838292480
# 15537    354035664192409602
# 15538    394574010794532865
# 15539    353130315277008897
# 15540    397521218192285696
# Name: tweet_id, dtype: object

# %%
negative_tweets = labled_data.filter(col("label") == 0).sample(False, 0.05, 123)

# %%
negative_tweets_pd = negative_tweets.toPandas()

# %%
negative_tweets_pd.shape
# Out:
# (6897456, 9)

# %%
us_labled_negative = negative_tweets_pd.loc[negative_tweets_pd['from_user'].str.lower().isin(users)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-03a20a6f5594> in <module>()
# ----> 1 us_labled_negative = negative_tweets_pd.loc[negative_tweets_pd['from_user'].str.lower().isin(users)]
#
# NameError: name 'negative_tweets_pd' is not defined

# %%
len(tweet_ids)
# Out:
# 1123617

# %%
us_labled_negative.to_csv('natdis_us_neg2.csv', encoding='UTF-8', index=False)

# %%
p = pd.read_csv("natdis_us.csv", dtype={'tweet_id': str}).dropna()
n = pd.read_csv("natdis_us_neg2.csv", dtype={'tweet_id': str}).dropna()

# %%
res2 = pd.concat([p, n])

# %%
id_subset = res2.tweet_id.iloc[30000:70000].tolist()

# %%
res.to_csv('natdis_us_tweets2.csv', encoding='utf-8', index=False)

# %%
res2 = pd.read_csv('natdis_us_tweets2.csv', dtype={'tweet_id': str})

# %%
res2
# Out:
#                    tweet_id   create_time     from_id        from_user  \
# 0        343103567302914048  1.370652e+09    31172792         cfdshark
# 1        344105385210294272  1.370890e+09   935451420   SandyUpdatesNY
# 2        317440764449808384  1.364533e+09   157597434       SHOUtime21
# 3        317448620343431168  1.364535e+09   494254456        salcamaro
# 4        410543672288350209  1.386734e+09   297428826    FirstNightArt
# 5        366029121278582784  1.376118e+09  1170711727   KirstinNoel722
# 6        372078318461276161  1.377560e+09   110753128           86Cane
# 7        505607979308032000  1.409396e+09    19850176  sandrasantander
# 8        485317857509904385  1.404558e+09  1394917244           NWSOPC
# 9        405101239891136512  1.385437e+09   112895255         tina5925
# 10       491790335509422081  1.406101e+09  2653486262         DaisaGee
# 11       491791421800599554  1.406102e+09   274575276      BigtimeTeez
# 12       428301499769569280  1.390968e+09   922174819      teresafink1
# 13       335841029280366592  1.368920e+09    16918575          adragon
# 14       521862354339123200  1.413271e+09   279164084  Watchdogsniffer
# 15       521870520628019200  1.413273e+09  1393369268        T58Sherry
# 16       399633192862228480  1.384133e+09   871021652     Breezy_Casas
# 17       406640952116129792  1.385804e+09   286336563        santithen
# 18       527715916604530689  1.414667e+09   232083082       Dorothayyy
# 19       508553035010670592  1.410098e+09    73165993       CYEKMYSTER
# 20       401133096965128192  1.384491e+09    19365373      KimWardMSRD
# 21       401136313975332864  1.384491e+09   473572273    JBalaoroPhoto
# 22       497155760493559809  1.407381e+09   124835193      mikeantolin
# 23       336773800534347777  1.369143e+09   263970953           abcWNN
# 24       336779290886668289  1.369144e+09   406672625  Dean_Journalist
# 25       364479896367546368  1.375748e+09    18042484        WCL_Shawn
# 26       380976672801308672  1.379681e+09   176543210   Le_Fashionisto
# 27       400556325618589696  1.384353e+09  1409024035     i_believe223
# 28       400561908257787904  1.384354e+09   101431372    jamieforlales
# 29       400563233628516352  1.384355e+09   367538965   louisette_chua
# ...                     ...           ...         ...              ...
# 1123587  547780451918544897  1.419454e+09    99515684  MetalInterviews
# 1123588  547823703581786112  1.419464e+09   408231636           HOT316
# 1123589  547868930736259073  1.419475e+09  2176769504       JayLucas01
# 1123590  547873318003433472  1.419476e+09  2156560602      monikahotte
# 1123591  547907853881987072  1.419484e+09    57799151    BLACKCARLITTO
# 1123592  547956348429025281  1.419496e+09   401059660     themegggster
# 1123593  547967777903214592  1.419499e+09   618225652    xXHappyM3alXx
# 1123594  547984974562226176  1.419503e+09    59544268      Stacey_Diaz
# 1123595  548137261347250176  1.419539e+09   538496244      TeddiLouise
# 1123596  548185516806791168  1.419551e+09  1315409396  Carlie_Mesheski
# 1123597  548352479470297088  1.419590e+09    25729884        lilydoyle
# 1123598  548372561789464576  1.419595e+09    46727954        fatima322
# 1123599  548728813392523264  1.419680e+09   214298134  REGINApizzeria_
# 1123609                                       LeelahAlcorn
# 1123610  coconutwater Coconut IShoweredwithCoco skincar...
# 1123611                               Champagne Champagnes
# 1123612                                         NHShootout
# 1123613                                        London jobs
# 1123614                                     FinishTheFight
# 1123615                                   BtVS Buffy tvtag
# 1123616                                          lifestyle
#
#                                location  \
# 0                     loc_charleston_sc
# 1                          loc_new_york
# 2                    loc_fremont__la_ca
# 3                           loc_markham
# 4                            loc_london
# 5                    loc_springfield_mo
# 6                           loc_florida
# 7            loc_los_angeles_california
# 8                   loc_college_park_md
# 9                     loc_manhattan_nyc
# 10                          loc_seattle
# 11                         loc_illinois
# 12       loc_norfolk_near_the_chesp_bay
# 13        loc_nyc_fl_and_on_your_screen
# 14                 loc_san_diego_ca_usa
# 15                loc_florida_panhandle
# 16                      loc_richland_wa
# 17              loc_whittier_california
# 18                       empty_location
# 19                         loc_paradise
# 20                   loc_los_angeles_ca
# 21           loc_san_francisco_bay_area
# 22                   loc_honoluluhawaii
# 23                    loc_new_york_city
# 24           loc_derry_northern_ireland
# 25                          loc_atlanta
# 26                 loc_san_francisco_ca
# 27                       empty_location
# 28                         loc_paradise
# 29                               loc_la
# ...                                 ...
# 1123587         loc_golden_colorado_usa
# 1123588                 loc_beaufort_sc
# 1123589                    loc_oklahoma
# 1123590                   loc_wisconsin
# 1123591                        loc_sqad
# 1123592             loc_williamsburg_va
# 1123593  loc_location_somewhere_smoking
# 1123594                 loc_c_a_l_i_â
# 1123595              loc_in_the_kitchen
# 1123596   loc_germany_âï¸sattyâï¸
# 1123597           loc_anywhere_but_here
# 1123598                   loc_las_vegas
# 1123599                     loc_peabody
# 1123600               loc_denver_co_usa
# 1123601                    loc_portland
# 1123602         loc_southern_california
# 1123603                        loc_1964
# 1123604        loc_casas_adobes_arizona
# 1123605                  loc_chicago_il
# 1123606                loc_arlington_va
# 1123607                    loc_maryland
# 1123608                  empty_location
# 1123609                    loc_new_york
# 1123610                    loc_illinois
# 1123611              loc_piedmont_italy
# 1123612                    loc_tampa_fl
# 1123613                 loc_los_angeles
# 1123614                      loc_dfw_tx
# 1123615                  loc_orlando_fl
# 1123616                        loc_boro
#
#                                                    mention  \
# 0                                            empty_mention
# 1                                            OccupySandyNJ
# 2                                            empty_mention
# 3                                        MapleLeafs JLupul
# 4                                           ZeanaRomanovna
# 5                                            empty_mention
# 6                                            Manny_Navarro
# 7                                                 quakesLA
# 8                                            empty_mention
# 9                                                     wspa
# 10                                                barbjonn
# 11                                           empty_mention
# 12                                              WeatherBug
# 13                                                 YouTube
# 14                                         stormchaser4850
# 15                                          weatherchannel
# 16                                                 TwainLe
# 17                                            OxfamAmerica
# 18                                           empty_mention
# 19                                                _Durdana
# 20                   CharityMiles WFP wwpinc lifeway_kefir
# 21                                                     ABC
# 22                                              pepperlive
# 23                                           empty_mention
# 24                                           empty_mention
# 25                                           empty_mention
# 26                                           empty_mention
# 27                             Cjquidetlabad Cjquidetlabad
# 28                                              Godstagram
# 29                                            MrsCalum5SOS
# ...                                                    ...
# 1123587                                      synmedia MfnH
# 1123588                                      MontriaWalker
# 1123589                                      empty_mention
# 1123590                                         dancintina
# 1123591                                        search4swag
# 1123592                                      empty_mention
# 1123593                                      empty_mention
# 1123594                                       Fresno_State
# 1123595                                      empty_mention
# 1123596                                      empty_mention
# 1123597                                      empty_mention
# 1123598                                         hellojudon
# 1123599                                            SexTaIk
# 1123600                                      empty_mention
# 1123601                                          Nashgrier
# 1123602                                           shhsMath
# 1123603                                      empty_mention
# 1123604                                        janinebucks
# 1123605                                      empty_mention
# 1123606                                      BEAUTIFULPlCS
# 1123607  sean_cahill10 purplekezza GriffFoundation Mara...
# 1123608                                    WestsideSociety
# 1123609                                      empty_mention
# 1123610                                           Kathneko
# 1123611                                           Decanter
# 1123612                                         NHShootout
# 1123613                                    LondonJobsAgent
# 1123614                         EminemsRealMrs CowboysYapp
# 1123615                                      empty_mention
# 1123616                                      empty_mention
#
#                                                       term  label
# 0                                                 hahahaha    1.0
# 1        rt two state hotlines established for elevatio...    1.0
# 2                clank clank clank clank clank clank clank    1.0
# 3        thats right folks turn that into a what a goal by    1.0
# 4                                       rt between two and    1.0
# 5        spending one of my days off going home to help...    1.0
# 6        rt video golden donofrio coley kehoe green and...    1.0
# 7        rt 243 magnitude 13 mi from tehachapi united s...    1.0
# 8        rgb airmass product shows losing tropical char...    1.0
# 9        rt our disaster teamsdr ian dacreis featured i...    1.0
# 10       rt tropical storm enters par codenamed henry t...    1.0
# 11       lightning show just above the clouds out here ...    1.0
# 12                                         rt rocks amp us    1.0
# 13       i didnt need a 1000 pound bike its a hard ride...    1.0
# 14       rt update forecast to become possibly the stro...    1.0
# 15       rt just in watch until 7am edt 6am cdt parts o...    1.0
# 16                                                      rt    1.0
# 17                    send a donation to to help survivors    1.0
# 18                   shes all lightening and wind and rain    1.0
# 19       rt update call this number for rescue in rajba...    1.0
# 20       starting early i ran 2018 4 s relief amp thx2 ...    1.0
# 21       3 things to do before donating to typhoon reli...    1.0
# 22                              praying for the big island    1.0
# 23       pic teacher hugs child briarwood elementary af...    1.0
# 24       do you know of anyone locally living in or who...    1.0
# 25       watching our sizzle reel of past hurricane cov...    1.0
# 26                                             courtesy of    1.0
# 27                                   rt for 1000 followers    1.0
# 28              rt make a change be good help other people    1.0
# 29       rt world wide donations water canned food rice...    1.0
# ...                                                    ...    ...
# 1123587  machine head video interview phil demmel amp d...    0.0
# 1123588                                     montria you on    0.0
# 1123589                  about to have no snow on like lol    0.0
# 1123590  rt we need to talk about kevin lynne ramsay th...    0.0
# 1123591        rt this is martin 18 killed by police 63134    0.0
# 1123592  ending my night by watching a christmas story ...    0.0
# 1123593                                            we know    0.0
# 1123594  spotted over yes santa hit shaw ave already ti...    0.0
# 1123595               merry christmas to all the ho ho hos    0.0
# 1123596                    be kind be grateful be fearless    0.0
# 1123597                         too much food way too much    0.0
# 1123598  had a best friend day with it was well needed ...    0.0
# 1123599                                     rt expect this    0.0
# 1123600             for sale 1965 c2 in showroom condition    0.0
# 1123601               i love u so much bae have a nice day    0.0
# 1123602         security is a very timely and needed topic    0.0
# 1123603  when you pick up a candy wrapper off your floo...    0.0
# 1123604  rt a very wimpy kid lee ivory childrens fictio...    0.0
# 1123605  who will shape the future how the new ala cent...    0.0
# 1123606  rt the grand canal in venice photo by pedro sz...    0.0
# 1123607  im so sad to hear that please meet some amazin...    0.0
# 1123608              rt good morning yall be amazing today    0.0
# 1123609  if youre not going to love your child uncondit...    0.0
# 1123610  rt blogged review of dial coconut water soap a...    0.0
# 1123611  rt ownlabel panel tasting 40 expertchosen s gi...    0.0
# 1123612  rt homewood flossmoor 58 archer 53 final ameri...    0.0
# 1123613  rt developeranalyst developer sharepointnet lo...    0.0
# 1123614  rt so suh is going to play on sunday good i do...    0.0
# 1123615               4x21 primeval scooby powers activate    0.0
# 1123616  already know 20 years from now im gonna own li...    0.0
#
# [1123617 rows x 9 columns]

# %%
id_subset_int
# Out:
# [460390026715484161,
#  460402018235195392,
#  460565327668326400,
#  460601268667703296,
#  460645212390322176,
#  460752871789563904,
#  460784907862945792,
#  460842944451575808,
#  460887597007769601,
#  460890658866479105,
#  460969771807154176,
#  460972170974220288,
#  460976642102677504,
#  461026566869237760,
#  461174676165644288,
#  461183173817151488,
#  461312211571331072,
#  461340133040484352,
#  461358726415654912,
#  461462476710633473,
#  461493535511158785,
#  461515710808596481,
#  461525919740342272,
#  461532014068260864,
#  461545297416425473,
#  461608849540407296,
#  461697299002163200,
#  461698091725619200,
#  461705427567513600,
#  461728605291020288,
#  461770707722985472,
#  461807944753881088,
#  461814856958873600,
#  461859501126475776,
#  461907525924036608,
#  461940644135833600,
#  462003806180352000,
#  462028175061811200,
#  462037268329295872,
#  462048722952519680,
#  462174791169245184,
#  462221792527282176,
#  462267124556529664,
#  462281360028090368,
#  462289681514631171,
#  462306869798002688,
#  462307817697718272,
#  462315191292919808,
#  462436553458208769,
#  462576043426320384,
#  462599397348343808,
#  462612596793692160,
#  462628338008215554,
#  462630980436496385,
#  462710932246765568,
#  462728430887653378,
#  462768352264351744,
#  462787570569863168,
#  462814057611788288,
#  462820797862510592,
#  462888913355685888,
#  462959939695026176,
#  462983939511291904,
#  462985420117000192,
#  463013744222552065,
#  463061806773460992,
#  463068513452965888,
#  463142203184119808,
#  463152407904411648,
#  463168652469370880,
#  463306972230868992,
#  463383522481557505,
#  463404594656063488,
#  463411141943648256,
#  463453022085849088,
#  463513944330469376,
#  463524878901977088,
#  463599575245152258,
#  463749387387031552,
#  463825660817833984,
#  463845273387536385,
#  463845504091058179,
#  463851715859464193,
#  463860762960621572,
#  463866853094195200,
#  463951796147195904,
#  464047749223022593,
#  464065382090027008,
#  464069920322375683,
#  464153697354657792,
#  464182373815308288,
#  464238623605686272,
#  464333544911683584,
#  464408027358322688,
#  464424498381725698,
#  464425559540248577,
#  464463215989379072,
#  464482660816261120,
#  464495319208955906,
#  464523907576639488,
#  464551074087845888,
#  464557520745660416,
#  464560729392431104,
#  464580501307928577,
#  464625267135500288,
#  464867211367047168,
*,\
/mnt/2b53fde0-61da-4eeb-a038-9910540ff9ad/Backup_tw_2013_11/2013-11/2013-11-*,\
/mnt/2b53fde0-61da-4eeb-a038-9910540ff9ad/Backup_tw_2013_12/2013-12/2013-12-*,\
/mnt/73dc2fdb-c49c-484c-bef8-7a6fc6abbc70/Backup_tw_2013_4/2013-04/2013-04-*,\
/mnt/73dc2fdb-c49c-484c-bef8-7a6fc6abbc70/Backup_tw_2013_5/2013-05/2013-05-*")

# %%
raw_data2 = sc.textFile("/mnt/73dc2fdb-c49c-484c-bef8-7a6fc6abbc70/Backup_tw_2014_1/2014-01/2014-01-*,\
/mnt/381c2633-4d72-4555-9be8-19e922cce4a1/Backup_tw_2014_2/2014-02/2014-02-*,\
/mnt/381c2633-4d72-4555-9be8-19e922cce4a1/Backup_tw_2014_3/2014-03/2014-03-*,\
/mnt/381c2633-4d72-4555-9be8-19e922cce4a1/Backup_tw_2014_4/2014-04/2014-04-*,\
/mnt/b93e71ec-8ddf-4033-bd42-770c05bc68aa/Backup_tw_2014_5/2014-05/2014-05-*,\
/mnt/b93e71ec-8ddf-4033-bd42-770c05bc68aa/Backup_tw_2014_6/2014-06/2014-06-*,\
/mnt/b93e71ec-8ddf-4033-bd42-770c05bc68aa/Backup_tw_2014_7/2014-07/2014-07-*,\
/mnt/4e8ba653-f2f0-4e18-a51e-458026833dee/Backup_tw_2014_8/2014-08/2014-08-*,\
/mnt/4e8ba653-f2f0-4e18-a51e-458026833dee/Backup_tw_2014_9/2014-09/2014-09-*,\
/mnt/4e8ba653-f2f0-4e18-a51e-458026833dee/Backup_tw_2014_10/2014-10/2014-10-*,\
/mnt/66e695cd-1a0c-4e3b-9a50-55e01b788529/Backup_tw_2014_11/2014-11/2014-11-*,\
/mnt/66e695cd-1a0c-4e3b-9a50-55e01b788529/Backup_tw_2014_12/2014-12/2014-12-*")

# %%
                        
/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/Backup_tw_2013_8/2013-08/2013-08-*,\
/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/Backup_tw_2013_9/2013-09/2013-09-*,\
/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/Backup_tw_2013_2/2013-02/2013-02-*,\
/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/Backup_tw_2013_3/2013-03/2013-03-*,\
/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/Backup_tw_2013_6/2013-06/2013-06-*,\
/mnt/2b53fde0-61da-4eeb-a038-9910540ff9ad/Backup_tw_2013_10/2013-10/2013-10-*,\
/mnt/2b53fde0-61da-4eeb-a038-9910540ff9ad/Backup_tw_2013_11/2013-11/2013-11-*,\
/mnt/2b53fde0-61da-4eeb-a038-9910540ff9ad/Backup_tw_2013_12/2013-12/2013-12-*,\
/mnt/73dc2fdb-c49c-484c-bef8-7a6fc6abbc70/Backup_tw_2013_4/2013-04/2013-04-*,\
/mnt/73dc2fdb-c49c-484c-bef8-7a6fc6abbc70/Backup_tw_2013_5/2013-05/2013-05-*,\
/mnt/73dc2fdb-c49c-484c-bef8-7a6fc6abbc70/Backup_tw_2014_1/2014-01/2014-01-*,\
/mnt/381c2633-4d72-4555-9be8-19e922cce4a1/Backup_tw_2014_2/2014-02/2014-02-*,\
/mnt/381c2633-4d72-4555-9be8-19e922cce4a1/Backup_tw_2014_3/2014-03/2014-03-*,\
/mnt/381c2633-4d72-4555-9be8-19e922cce4a1/Backup_tw_2014_4/2014-04/2014-04-*,\
/mnt/b93e71ec-8ddf-4033-bd42-770c05bc68aa/Backup_tw_2014_5/2014-05/2014-05-*,\
/mnt/b93e71ec-8ddf-4033-bd42-770c05bc68aa/Backup_tw_2014_6/2014-06/2014-06-*,\
/mnt/b93e71ec-8ddf-4033-bd42-770c05bc68aa/Backup_tw_2014_7/2014-07/2014-07-*,\
/mnt/4e8ba653-f2f0-4e18-a51e-458026833dee/Backup_tw_2014_8/2014-08/2014-08-*,\
/mnt/4e8ba653-f2f0-4e18-a51e-458026833dee/Backup_tw_2014_9/2014-09/2014-09-*,\
/mnt/4e8ba653-f2f0-4e18-a51e-458026833dee/Backup_tw_2014_10/2014-10/2014-10-*,\
/mnt/66e695cd-1a0c-4e3b-9a50-55e01b788529/Backup_tw_2014_11/2014-11/2014-11-*,\
/mnt/66e695cd-1a0c-4e3b-9a50-55e01b788529/Backup_tw_2014_12/2014-12/2014-12-*")

# %%
positive_ids = p.tweet_id.tolist()

# %%
len(positive_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-ce8706d991de> in <module>()
# ----> 1 len(positive_ids)
#
# NameError: name 'positive_ids' is not defined

# %%
import json
    
# Remove invalid tweet which has length less than 1000.
def valid_json(d):
    return len(d) > 1000

# load json object, if a line is invalid, substitute as an empty dict (which has len() == 0 )
def load_json(d):
    try:
        js = json.loads(d)
        
    except ValueError as e:
        js = {}
        
    except Exception:
        js = {}
        
    return js

def raw_parser(d):
    tweet_id = int(d['id'])
    raw_text = d['text']

    if tweet_id in id_subset_int:
        return {"tweet_id": tweet_id, 
                "raw_text": raw_text}
    else:
        return {"tweet_id": 0, 
               "raw_text": None}
    
#    return processed

def us_ids(d):
    return d['tweet_id'] != 0

# %%
data_rdd = raw_data.filter(valid_json).map(load_json).filter(lambda x: len(x) > 1).map(raw_parser).filter(us_ids)

# %%
data_rdd2 = raw_data2.filter(valid_json).map(load_json).filter(lambda x: len(x) > 1).map(raw_parser).filter(us_ids)

# %%
#3.588733114946724e+17
a = data_rdd.take(1)[0]

# %%
data_rdd.take(10)
# Out:
# [{'raw_text': u'RT @frost_ella: \u201c@AboutAquarius: An #Aquarius will act crazy whenever and wherever they please.\u201d @silvaangold',
#   'tweet_id': 343594401555169280},
#  {'raw_text': u"Only 6 hours and 40 minutes till I work and I can't fall asleep. #gonnabealongday",
#   'tweet_id': 343598285489045504},
#  {'raw_text': u'RT @Southern_Voices: "I don\'t do lonely well" - #JasonAldean',
#   'tweet_id': 343605776503414784},
#  {'raw_text': u'Only 20 more minutes. Lets hold tough on D, attack the net up front, and get some god damn goals!!! #LETSGOHAWKS #LASucks',
#   'tweet_id': 343550348763463680},
#  {'raw_text': u'I am so loving Tyler Toffoli.  #LAKings',
#   'tweet_id': 343576877727879170},
#  {'raw_text': u'my feet are killing me. #serverprobz',
#   'tweet_id': 343577485901967360},
#  {'raw_text': u'I wish more of my friends were on twitter. #lonely #digitalage #getwithit',
#   'tweet_id': 343654539490115586},
#  {'raw_text': u'100ft slip and slide on deck at 130 east Jeff #bringbitches',
#   'tweet_id': 343413689958928388},
#  {'raw_text': u'@NiallOfficial #crazymofos NIALL PLEASE FOLLOW ILYSM 45',
#   'tweet_id': 343420417630957569},
#  {'raw_text': u'@NiallOfficial #crazymofofollowspree please follow me niall! ilysm and itd mean the world to me \U0001f40c',
#   'tweet_id': 343421763981570048}]

# %%
id_subset_int[21545]
# Out:
# 343594401555169280

# %%
schema = StructType([StructField('tweet_id', StringType(), False),
                     StructField('raw_text', StringType(), True),
                    ])

# %%
data_df = sqlContext.createDataFrame(data_rdd, schema)

# %%
data_df2 = sqlContext.createDataFrame(data_rdd2, schema)

# %%
data_df.write.save("/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/us_natdis/2013_Raw_txt.parquet", format="parquet")

# %%
data_df2.write.save("/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/us_natdis/2014_Raw_txt1.parquet", format="parquet")

# %%
s = spark.read.parquet("/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/us_natdis/2014_Raw_txt1.parquet")

# %%
s_pd = s.toPandas()

# %%
s_pd.shape
# Out:
# (22916, 2)

# %%
texts = pd.DataFrame()

# %%
s_pd = s_pd.drop_duplicates()

# %%
texts = texts.append(s_pd)

# %%
texts.shape
# Out:
# (22876, 2)

# %%
# 4236
# 13351
# 22051

s_pd.shape
# Out:
# (7645, 2)

# %%
res2 = pd.read_csv('natdis_us_tweets2.csv', dtype={'tweet_id': str})

# %%
res_with_rawtext = res2.join(s_pd.set_index("tweet_id"), how="right", on="tweet_id", lsuffix="c_", rsuffix="o_")

# %%
res_with_rawtext = res_with_rawtext.drop_duplicates(subset='tweet_id')

# %%
res_with_rawtext = res_with_rawtext.drop("term", axis=1)

# %%
res_with_rawtext
# Out:
#                  tweet_id   create_time     from_id        from_user  \
# 30000  460390026715484161  1.398615e+09  2254947145      DDaystripes
# 30001  460402018235195392  1.398618e+09    21497938      whatsananna
# 30002  460565327668326400  1.398657e+09   612509501     LambentLucky
# 30003  460601268667703296  1.398665e+09   523388470        MaraZupko
# 30004  460645212390322176  1.398676e+09   199128850        SeegarsLu
# 30005  460752871789563904  1.398701e+09  2393736830     jacobpaul710
# 69992  524428932813037568  1.413883e+09  1909604815      tradeanrodw
# 69993  524559010779774976  1.413914e+09    21521779      Stacy_Carey
# 69994  524562806621077504  1.413915e+09   301537246  HeatherFarmer22
# 69995  524626937541443584  1.413930e+09   598967536    GodoyMarcos00
# 69996  524636735435972609  1.413933e+09    20817529        joehick58
# 69997  524711540843622400  1.413950e+09    20024047          beta510
# 69998  524713776386686976  1.413951e+09    15617163    HawkOfTheMist
# 69999  524714137101041664  1.413951e+09    15955423     westonprobst
#
#                                                  hashtag  \
# 30000                                               DDay
# 30001                                   TEDxGrandviewAve
# 30002                                          SpiderMan
# 30003                                StopWhitePeople2014
# 30004                                           HOUvsPOR
# 30005                                         IThappened
# 30006                                                MCM
# 30007                         etsymnt mothersdaygiftidea
# 30008      nosmoking vape goodmorning coffee paulstanley
# 30009                                      LaLaDickinson
# 30010                                          PennState
# 30011                                     MeatlessMonday
# 30012                                              RDMAs
# 30013                                             Virgos
# 30014                                                RNS
# 30015                                            science
# 30016                                 DanceMoms GirlTalk
# 30017                                vitashare blackgate
# 30018                                           dcRising
# 30019                                   financialexpress
# 30020                                   ovdmostbeautiful
# 30021                                         BigBrewDay
# 30022                                          ragetweet
# 30023    Spring shows AL GA SC FL Grind heworkin tbg lno
# 30024                                overit yousounddumb
# 30025    CamTo2Mil CamTo2Million CamTo2Mil CamTo2Million
# 30026                                                WCW
# 30027  99cents asmsg aga3 bynr iartg zyngbooks RReBoo...
# 30028                                             RochMN
# 30029                                            TeamP1F
# ...                                                  ...
# 69970                                         SaveDallas
# 69971         porn hot sex teen xxx cum pic tube Shemale
# 69972                                     Life getbetter
# 69973                                              Aries
# 69974                        MD1 Red2Blue TNTweeters CIR
# 69975                                HiWelcometoPizzahut
# 69976             snapchat adland getready millenialfury
# 69977                                              Colts
# 69978                              Negotiator teamplayer
# 69979                             dopesessionscomingsoon
# 69980                                           thankyou
# 69981                                              49ers
# 69982                                           Dominion
# 69983                         EMABiggestFansJustinBieber
# 69984                                            vzwbuzz
# 69985                                       workfromhome
# 69986                                      SettleDownNow
# 69987                            SomethingBigIsHappening
# 69988                                  WendyDavisWontSay
# 69989                                 MotherNatureMonday
# 69990                                      HandsOffMyGun
# 69991                                       Houston Jobs
# 69992                                        Inbound2014
# 69993                           19kids 19kidsandcounting
# 69994                                         wellearned
# 69995                                           rattpack
# 69996                                      TurnerForOhio
# 69997                                           gogiants
# 69998                                              photo
# 69999                                        WorldSeries
#
#                                  location  \
# 30000             loc_york_united_kingdom
# 30001                            loc_iowa
# 30002                       loc_southeast
# 30003                    loc_never_russia
# 30004                      loc_houston_tx
# 30005          loc_lake_charles_louisiana
# 30006                         loc_navarre
# 30007                   loc_south_bend_wa
# 30008                loc_san_francisco_ca
# 30009  loc_â_atlanta_miami_cali__uk_â
# 30010                   loc_washington_dc
# 30011            loc_empire_state_of_mind
# 30012                    loc_hollywood_ca
# 30013                          loc_18__tx
# 30014         loc_ig_internationaljones12
# 30015                        loc_michigan
# 30016                     loc_appleton_wi
# 30017                   loc_fort_worth_tx
# 30018                       loc_fitchburg
# 30019                           loc_india
# 30020                   loc_tuscaloosa_al
# 30021                        loc_colorado
# 30022                      empty_location
# 30023                         loc_atlanta
# 30024                       loc_austin_tx
# 30025                        loc__25_112_
# 30026                  loc_planes__hotels
# 30027                      empty_location
# 30028                       loc_minnesota
# 30029                            loc_cali
# ...                                   ...
# 69970                       loc_louisiana
# 69971                  loc_pittsburghpaus
# 69972                      loc_fort_myers
# 69973                             loc_c_a
# 69974                  loc_los_angeles_ca
# 69975                           loc_texas
# 69976                        loc_brooklyn
# 69977                 loc_indianapolis_in
# 69978                     loc_evanston_il
# 69979                            loc_ohio
# 69980               loc_newark_new_jersey
# 69981                        loc_bay_area
# 69982                      loc_california
# 69983                loc_watson_louisiana
# 69984                      loc_new_mexico
# 69985              loc_charlotte_nc_28202
# 69986              loc_san_luis_obispo_us
# 69987                      empty_location
# 69988         loc_williamson_county_texas
# 69989                       loc_chicagoil
# 69990                           loc_texas
# 69991                      loc_houston_tx
# 69992                        loc_new_york
# 69993                       loc_minnesota
# 69994                         loc_florida
# 69995                         loc_anaheim
# 69996                          loc_philly
# 69997                     loc_berkeley_ca
# 69998                           loc_texas
# 69999                        loc_tulsa_ok
#
#                                                  mention  label  \
# 30000                                      empty_mention    0.0
# 30001                                        baron_batch    0.0
# 30002                                     SpiderManMovie    0.0
# 30003                                     TweetLikeAGirI    0.0
# 30004                                      empty_mention    0.0
# 30005                                      Chase widowtx    0.0
# 30006                                           J4CKMULL    0.0
# 30007                                    Bessiescreation    0.0
# 30008                                      empty_mention    0.0
# 30009                         LaLaTheBeauty SimplyLaLaTV    0.0
# 30010                                     RivalsFriedman    0.0
# 30011                                      empty_mention    0.0
# 30012                             olivia_holt PeytonList    0.0
# 30013                                        AboutVirgos    0.0
# 30014                                      empty_mention    0.0
# 30015  rabidatheistgay NotGayDalek DougDauntless Sand...    0.0
# 30016                          DanceMoms Abby_Lee_Miller    0.0
# 30017                                      empty_mention    0.0
# 30018                                RBBallWiz John_Wall    0.0
# 30019                                      empty_mention    0.0
# 30020                                      empty_mention    0.0
# 30021                                     DryDockBrewing    0.0
# 30022                                          deephanen    0.0
# 30023                                      empty_mention    0.0
# 30024                                      empty_mention    0.0
# 30025                           xojazmiinn camerondallas    0.0
# 30026                                      empty_mention    0.0
# 30027                      laurencestjohn laurencestjohn    0.0
# 30028                                MayoClinic ABC6NEWS    0.0
# 30029                                      prettyflaccco    0.0
# ...                                                  ...    ...
# 69970                                      MitchPileggi1    0.0
# 69971                                      empty_mention    0.0
# 69972                                      empty_mention    0.0
# 69973                                        BestofAries    0.0
# 69974                         TNTweetersMD TilghmanForMD    0.0
# 69975                                      jazminnaseret    0.0
# 69976                                      empty_mention    0.0
# 69977                                      empty_mention    0.0
# 69978                                      KelloggSchool    0.0
# 69979                                      BitchMobGod69    0.0
# 69980                        ShamekaCBrown DashawnTaylor    0.0
# 69981                                      empty_mention    0.0
# 69981  Joe Looney is now at center, Jonathan Martin a...
# 69982  RT @MrTomWisdom: P.S. Can't wait to see what @...
# 69983  RT @BieberFtFIores: @justinbieber when you sin...
# 69984  Disney Family Movies Free Preview Through The ...
# 69985  RT @mlmdiary: 7 states where the most people w...
# 69986  RT @TheRealPSL: Someone just ordered me extra ...
# 69987  RT @ShawnMendes: So should I tell you when #So...
# 69988  RT @liars_never_win: #WendyDavisWontSay where ...
# 69989  @NigelBarker oh my word Nigel this is Phenomen...
# 69990  RT @theblaze: Why did @dloesch fight for this ...
# 69991  #Houston #Jobs Recruiter - Sales: Houston Equa...
# 69992  RT @abiondo: #Inbound2014 Social Media Actuall...
# 69993  '19 Kids And Counting' Spoilers: More Wedding ...
# 69994  Big shout out to @rachelben0 on defender of th...
# 69995  RT @mrajab24: Bouta be #1 on iTunes 🙏🙏🙏 #rattp...
# 69996  @TheReidReport @jerryspringer @JoyAnnReid @nin...
# 69997                       Almost game time!! #gogiants
# 69998  I don't know what to say about this one. Reall...
# 69999  RT @MLB: James Shields fires the first pitch a...
#
# [22876 rows x 9 columns]

# %%
res_with_rawtext.to_csv("us_tweets_rawtext_p2.csv", encoding='utf-8', index=False)

# %%
t = data_df.filter(data_df.tweet_id == tweet_ids[0])

# %%
id = tweet_ids[0]

# %%
test = pd.read_csv("us_tweets_rawtext_p2.csv", lineterminator='\n')

# %%
test
# Out:
#                  tweet_id   create_time     from_id        from_user  \
# 0      460390026715484161  1.398615e+09  2254947145      DDaystripes
# 1      460402018235195392  1.398618e+09    21497938      whatsananna
# 2      460565327668326400  1.398657e+09   612509501     LambentLucky
# 3      460601268667703296  1.398665e+09   523388470        MaraZupko
# 4      460645212390322176  1.398676e+09   199128850        SeegarsLu
# 5      460752871789563904  1.398701e+09  2393736830     jacobpaul710
# 6      460784907862945792  1.398709e+09   549574913       _loudiseoh
# 7      460842944451575808  1.398723e+09  1275774684      BeBe_Powers
# 8      460887597007769601  1.398734e+09   193193669       BABEL_ROCK
# 9      460890658866479105  1.398734e+09   193198150    LaLaTheBeauty
# 10     460969771807154176  1.398753e+09   114578219     robhollandjr
# 11     460972170974220288  1.398754e+09   170130930  BlackBerry_Mama
# 12     460976642102677504  1.398755e+09   598555086   Viviana_Tafuri
# 13     461026566869237760  1.398767e+09   769787749  Sharon_Ceballos
# 14     461174676165644288  1.398802e+09  2232625687  EverybodyJonesn
# 15     461183173817151488  1.398804e+09  2347059907    JeffPanshov68
# 16     461312211571331072  1.398835e+09  1482728275      O10Courtney
# 17     461340133040484352  1.398841e+09     1529611        GeminiAce
# 18     461358726415654912  1.398846e+09   175835729         Steague3
# 19     461462476710633473  1.398871e+09   333223535           vuukle
# 20     461493535511158785  1.398878e+09    46425182  OverdriveUpdate
# 21     461515710808596481  1.398883e+09  2377319796    CraftColorado
# 22     461525919740342272  1.398886e+09   127841438    taylordevore5
# 23     461532014068260864  1.398887e+09    30828929       slap_music
# 24     461545297416425473  1.398890e+09    56219523          sjp1120
# 24                                   overit yousounddumb
# 25       CamTo2Mil CamTo2Million CamTo2Mil CamTo2Million
# 26                                                   WCW
# 27     99cents asmsg aga3 bynr iartg zyngbooks RReBoo...
# 28                                                RochMN
# 29                                               TeamP1F
# ...                                                  ...
# 22846                                         SaveDallas
# 22847         porn hot sex teen xxx cum pic tube Shemale
# 22848                                     Life getbetter
# 22849                                              Aries
# 22850                        MD1 Red2Blue TNTweeters CIR
# 22851                                HiWelcometoPizzahut
# 22852             snapchat adland getready millenialfury
# 22853                                              Colts
# 22854                              Negotiator teamplayer
# 22855                             dopesessionscomingsoon
# 22856                                           thankyou
# 22857                                              49ers
# 22858                                           Dominion
# 22859                         EMABiggestFansJustinBieber
# 22860                                            vzwbuzz
# 22861                                       workfromhome
# 22862                                      SettleDownNow
# 22863                            SomethingBigIsHappening
# 22864                                  WendyDavisWontSay
# 22865                                 MotherNatureMonday
# 22866                                      HandsOffMyGun
# 22867                                       Houston Jobs
# 22868                                        Inbound2014
# 22869                           19kids 19kidsandcounting
# 22870                                         wellearned
# 22871                                           rattpack
# 22872                                      TurnerForOhio
# 22873                                           gogiants
# 22874                                              photo
# 22875                                        WorldSeries
#
#                                  location  \
# 0                 loc_york_united_kingdom
# 1                                loc_iowa
# 2                           loc_southeast
# 3                        loc_never_russia
# 4                          loc_houston_tx
# 5              loc_lake_charles_louisiana
# 6                             loc_navarre
# 7                       loc_south_bend_wa
# 8                    loc_san_francisco_ca
# 9      loc_â_atlanta_miami_cali__uk_â
# 10                      loc_washington_dc
# 11               loc_empire_state_of_mind
# 12                       loc_hollywood_ca
# 13                             loc_18__tx
# 14            loc_ig_internationaljones12
# 15                           loc_michigan
# 16                        loc_appleton_wi
# 17                      loc_fort_worth_tx
# 18                          loc_fitchburg
# 19                              loc_india
# 20                      loc_tuscaloosa_al
# 21                           loc_colorado
# 22                         empty_location
# 23                            loc_atlanta
# 24                          loc_austin_tx
# 25                           loc__25_112_
# 26                     loc_planes__hotels
# 27                         empty_location
# 28                          loc_minnesota
# 29                               loc_cali
# ...                                   ...
# 22846                       loc_louisiana
# 22847                  loc_pittsburghpaus
# 22848                      loc_fort_myers
# 22849                             loc_c_a
# 22850                  loc_los_angeles_ca
# 22851                           loc_texas
# 22852                        loc_brooklyn
# 22853                 loc_indianapolis_in
# 22854                     loc_evanston_il
# 22855                            loc_ohio
# 22856               loc_newark_new_jersey
# 22857                        loc_bay_area
# 22858                      loc_california
# 22859                loc_watson_louisiana
# 22860                      loc_new_mexico
# 22861              loc_charlotte_nc_28202
# 22862              loc_san_luis_obispo_us
# 22863                      empty_location
# 22864         loc_williamson_county_texas
# 22865                       loc_chicagoil
# 22866                           loc_texas
# 22867                      loc_houston_tx
# 22868                        loc_new_york
# 22869                       loc_minnesota
# 22870                         loc_florida
# 22871                         loc_anaheim
# 22872                          loc_philly
# 22873                     loc_berkeley_ca
# 22874                           loc_texas
# 22875                        loc_tulsa_ok
#
#                                                  mention  label  \
# 0                                          empty_mention    0.0
# 1                                            baron_batch    0.0
# 2                                         SpiderManMovie    0.0
# 3                                         TweetLikeAGirI    0.0
# 4                                          empty_mention    0.0
# 5                                          Chase widowtx    0.0
# 6                                               J4CKMULL    0.0
# 7                                        Bessiescreation    0.0
# 8                                          empty_mention    0.0
# 9                             LaLaTheBeauty SimplyLaLaTV    0.0
# 10                                        RivalsFriedman    0.0
# 11                                         empty_mention    0.0
# 12                                olivia_holt PeytonList    0.0
# 13                                           AboutVirgos    0.0
# 14                                         empty_mention    0.0
# 15     rabidatheistgay NotGayDalek DougDauntless Sand...    0.0
# 16                             DanceMoms Abby_Lee_Miller    0.0
# 17                                         empty_mention    0.0
# 18                                   RBBallWiz John_Wall    0.0
# 19                                         empty_mention    0.0
# 20                                         empty_mention    0.0
# 21                                        DryDockBrewing    0.0
# 22                                             deephanen    0.0
# 23                                         empty_mention    0.0
# 24                                         empty_mention    0.0
# 25                              xojazmiinn camerondallas    0.0
# 26                                         empty_mention    0.0
# 27                         laurencestjohn laurencestjohn    0.0
# 28                                   MayoClinic ABC6NEWS    0.0
# 29                                         prettyflaccco    0.0
# ...                                                  ...    ...
# 22846                                      MitchPileggi1    0.0
# 22847                                      empty_mention    0.0
# 22848                                      empty_mention    0.0
# 22849                                        BestofAries    0.0
# 22850                         TNTweetersMD TilghmanForMD    0.0
# 22851                                      jazminnaseret    0.0
# 22852                                      empty_mention    0.0
# 22853                                      empty_mention    0.0
# 22854                                      KelloggSchool    0.0
# 22855                                      BitchMobGod69    0.0
# 22856                        ShamekaCBrown DashawnTaylor    0.0
# 22857                                      empty_mention    0.0
# 22858                            MrTomWisdom VaunWilmott    0.0
# 22859                        BieberFtFIores justinbieber    0.0
# 22860                                      empty_mention    0.0
# 22861                                  mlmdiary mlmdiary    0.0
# 22862                                         TheRealPSL    0.0
# 22863                                        ShawnMendes    0.0
# 22864                                    liars_never_win    0.0
# 22865                                        NigelBarker    0.0
# 22866                                   theblaze DLoesch    0.0
# 22867                                      empty_mention    0.0
# 22868                                            abiondo    0.0
# 22869                                      empty_mention    0.0
# 22870                                         rachelben0    0.0
# 22871                                  mrajab24 Logic301    0.0
# 22872  TheReidReport jerryspringer JoyAnnReid ninaturner    0.0
# 22873                                      empty_mention    0.0
# 22874                                      empty_mention    0.0
# 22875                                                MLB    0.0
#
#                                                 raw_text
# 0      We've updated our website and added a page for...
# 1      Thinking about @baron_batch and #TEDxGrandview...
# 2      RT @SpiderManMovie: Find out what fate has in ...
# 3      RT @TweetLikeAGirI: #StopWhitePeople2014 http:...
# 4      That was worse than the ending of "Jeepers Cre...
# 5                            @Chase @widowtx #IThappened
# 6      RT @J4CKMULL: Oh your boyfriend is you "#MCM" ...
# 7      RT @Bessiescreation: Mamas day is just around ...
# 8      One week #nosmoking and back on the #vape #goo...
# 9      "Undeniably The Girl Next Door" #LaLaDickinson...
# 10     RT @RivalsFriedman: #PennState hosting 2015 DE...
# 11     #MeatlessMonday was a success. Mash'd cauliflo...
# 12     Great pics of @olivia_holt @PeytonList at the ...
mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/us_natdis/us_tweets_rawtext_p1.csv")

# %%
te.shape
# Out:
# (44571, 9)

# %% [markdown]
# \

# %%
temporal_split_directory = '/mnt/1e69d2b1-91a9-473c-a164-db90daf43a3d/splitted_data/'

topic = "Natr_Disaster"

train_pd = pd.read_csv(temporal_split_directory + topic + "/training.csv").dropna()
validation_pd = pd.read_csv(temporal_split_directory + topic + "/validation.csv").dropna()
test_pd = pd.read_csv(temporal_split_directory + topic + "/test.csv").dropna().reset_index()

test = test_pd.drop_duplicates(subset='term').reset_index()
valid = validation_pd.drop_duplicates(subset='term').reset_index()
train = train_pd.drop_duplicates(subset='term').reset_index()

tf = TestFramework(train, valid, test)
# Out:
# /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Initializing Classifier....
# Complete!

# %%
test_features = test.drop('label', axis=1)
test_target = test['label']

predictions = tf.get_pipeline().predict_proba(test_features)[:, 1]

# %%
test['prob'] = predictions

# %%
users = pd.read_csv('users.txt', sep=" ", header=None)
user_list = users.values.tolist()
users = [u[0] for u in user_list]

# %%
users
# Out:
# ['meganasty_',
#  'investorjunkie',
#  'susanschlegel',
#  '4beem',
#  'gabewist97',
#  'gabewist97',
#  'hopscans',
#  'erica_boone',
#  'erica_boone',
#  'ajcfoodandmore',
#  'jkravitz',
#  'mothergothel23',
#  'iangiles15',
#  'donandrewbailey',
#  'ibrandonleeb',
#  'tbrad_',
#  'relentlessfmwrx',
#  'jm_cali',
#  'hpconvergedsys',
#  'hpconvergedsys',
#  'jessjquinones',
#  'vessel_sf',
#  'hank_hammond',
#  'attitudechick9',
#  'carlitaax33',
#  'rainface92_',
#  'sellabella_babi',
#  'tyleredavis99',
#  'sassyhotmesss',
#  'traycehood',
#  'skinnyminnilia',
#  'skinnyminnilia',
#  'elliotlikescats',
#  'keyser_roll',
#  'alina_horne',
#  'itsbaybiegurl',
#  'wumezycubure',
#  'olibattles',
#  'olibattles',
#  'imcallinudaddy_',
#  'aknight128',
#  'kalilee',
#  'kat_white',
#  'cliffordg27',
#  '_runninjonesy_',
#  '_runninjonesy_',
#  'bdostrem',
#  'bdostrem',
#  'ravenguenette',
#  'texasrangersluv',
#  'connorduane',
#  'arielceleste_',
#  'arielceleste_',
#  'jensenjones_',
#  'jensenjones_',
#  'elienhart',
#  'gschultz07',
#  'ayeitsalexys',
#  'linktobob',
#  'youppldntcare',
#  'cduren25',
#  'cduren25',
#  'ryanvsoreal',
#  'lejoyeuse',
#  'ciera_tyler',
#  'robbtodd',
#  'colbyswartz',
#  'dwarfsandgiant',
#  'joshschmitz3',
#  'mattarena',
#  'mattarena',
#  'mp_fonseca24',
#  'mtwigg23',
#  'mtwigg23',
#  'thatman_jshort',
#  'tarahahl',
#  'lovelybee07',
#  'callme_cinnabon',
#  'cham3leonsoul',
#  'goingcommando33',
#  'tvdbelieber1998',
#  'co111n',
#  'joeyerardi',
#  'crankenspank',
#  'jordyn_hale74',
#  'nikkihendry',
#  'stevestowers',
#  'michellekhlot',
#  'aguselizeche',
#  'katiebeardeaux',
#  'tweaksallen442',
#  'aliahkay',
#  'aliahkay',
#  'monroe_nerfwars',
#  'monroe_nerfwars',
#  'lawwwin',
#  'lawwwin',
#  'doncoquiwp',
#  'miajop',
#  'miajop',
#  'drxwski',
#  'kennethedwards',
#  'marleygrealis',
#  'krepticecho',
#  'noseyrhosey',
#  'robertodelcarpi',
#  'witty27',
#  'witty27',
#  'tomwchapman',
#  'prince_deron',
#  'lilyonahfans',
#  'monicasey',
#  'haley_backup',
#  'geek_squad33',
#  '_trishchua',
#  'rosanti_maison',
#  'm_rowlands1',
#  'invariablydrew',
#  'invariablydrew',
#  'esorrentino24',
#  'whm00116',
#  'sofiadahooligan',
#  'cyntheeea',
#  'simbastatus',
#  'sirstanstanley',
#  'aramarie_b',
#  'shoegazr13',
#  'shoegazr13',
#  'benjaminhccarr',
#  'qveennj__',
#  'thesinfulbitch',
#  '_lifeassianna',
#  'kameronkemnitz',
#  '1direction312',
#  'richardfrisch',
#  'suppaduppakevin',
#  'amran2012',
#  'amran2012',
#  'piercethe_hemmo',
#  'silverrecstasy',
#  'silverrecstasy',
#  'hurtslikehunter',
#  'cmpearls',
#  'cmpearls',
#  'jleuzzi17',
#  'diqueemily_',
#  'ilovebieber622',
#  'rcoxjr2',
#  'pitman_mark',
#  'robinette10',
#  'tori_critz',
#  'krisculby',
#  'kimberlybalaun',
#  'kimberlybalaun',
#  'iamcbesse',
#  'amusesme',
#  'thatoneninja512',
#  'thatoneninja512',
#  'cadbandri',
#  'goneastray84',
#  'hoytbowhunter94',
#  'whdd',
#  'damonelena08',
#  'platinumpropntr',
#  'nicholasmaroney',
#  'iseecolin',
#  'staycold_xxx',
#  'natalieedorsch',
#  'isiejahallen',
#  'lesliewatt99',
#  'oohmykel',
#  'adicortez',
#  'aamberanderson',
#  'lifeaquadic',
#  'gabybarragan408',
#  'itskendramartin',
#  'itskendramartin',
#  '6thr',
#  'banana_anna14',
#  'nina_ramon',
#  'omadyle',
#  'saratogacasino',
#  'mria_ncole',
#  'lexychanster',
#  'k_dimarco',
#  'floralxniall',
#  'iamsirfranklin',
#  'iamsirfranklin',
#  'alexxandria09',
#  'jairoe__',
#  'jairoe__',
#  'tiffy_tiffany11',
#  'sireenshaban',
#  'smokiee_420',
#  '_boxerbriefs',
#  'lovelyymercedes',
#  'estrellagisell',
#  'willhulshof',
#  'willhulshof',
#  'landertune',
#  'sadgirlselfharm',
#  'jimmyjamesla',
#  'woahredix',
#  'woahredix',
#  'daviddsi',
#  'cre_jus',
#  'cre_jus',
#  'andrewmackenzie',
#  'heaav_b',
#  'melanieghan',
#  'superslugger08',
#  'andrewpall18',
#  'crownedroyal_la',
#  'basedgawduchiha',
#  'johngile',
#  'playyacardsrght',
#  'jenna_kilpela',
#  'hairyspiderlegs',
#  'philcashout',
#  'philcashout',
#  'zachtbott',
#  'thermalkat',
#  'swilliamsxp',
#  'chadwilken',
#  'screammylullaby',
#  'zakipoint',
#  'montesnate',
#  'lancerl0t',
#  'lancerl0t',
#  'og_siestas',
#  'toxicfume_',
#  'gctilla',
#  'gctilla',
#  'g1105',
#  'mprice2014',
#  'jazzberries22',
#  'bradhowardii_8',
#  'hatredz_past15',
#  'hatredz_past15',
#  'blaynehayes07',
#  'blaynehayes07',
#  'anier27',
#  'stharr1s',
#  'digiears',
#  'tollneralle3',
#  'aden_johnston3',
#  'aden_johnston3',
#  'maduhee',
#  'destinynickole1',
#  'shannx94',
#  'stuartgraves2',
#  'jakecro6',
#  'jakecro6',
#  'dezmond1218',
#  '_amtwoflyy',
#  'mucampussafety',
#  'zmcfarlen',
#  'hsternenberg',
#  'dancarlsen',
#  'vanzamakerdance',
#  'robwall777',
#  'rhett_musser',
#  'lezama_haydee',
#  'mellmurda_',
#  'erickreyes_',
#  'erickreyes_',
#  'lovelykirby_94',
#  'kristinownz',
#  'wilsonsd121',
#  'agriffin7017',
#  'mslo84',
#  'mslo84',
#  'liveinvictory',
#  'auktane',
#  'iamsinatraa',
#  'amers212',
#  'jennamariie1998',
#  'jennamariie1998',
#  'edwardnational',
#  'fcastroacuna',
#  'kickz_cover',
#  'kayleee_ann',
#  'kelliott34',
#  'loveeekarina',
#  'tanner_diaz',
#  'msaishathapoet',
#  'kevinw_espn',
#  'oreoismydream',
#  'dovxx_',
#  '97astronautkid',
#  'cait90113',
#  'tonypiacente',
#  'jamestbritt',
#  'coronadoapril',
#  'ugochi_ihemeson',
#  'sarahnowell__',
#  'kenkouot',
#  'ummheyitslauren',
#  'georgiahiipakka',
#  'georgiahiipakka',
#  'jojohighass',
#  'velifrmthaend',
#  'allenshircliff1',
#  'chistaci',
#  'zballinn',
#  'zballinn',
#  'superandomness',
#  'madelaine_ryan',
#  'hannahesimp28',
#  'voteforcraiggg',
#  'powerhousegains',
#  'olympiatrottier',
#  'olympiatrottier',
#  'sra_l_p_m',
#  'rivertonjoe',
#  'ocband',
#  'ocband',
#  '_jmagnus',
#  'state_machine',
#  'iamyannafame',
#  'iamyannafame',
#  'chaneltatum',
#  'stans_unite',
#  'tgrafft',
#  'nell_bell913',
#  'erikacarlock',
#  'thatniggaprizzy',
#  'annikaadavis',
#  'annikaadavis',
#  'aoagov',
#  'chyymottu',
#  'chazico',
#  'chazico',
#  'sssstringer',
#  'turnthepageny',
#  'kaylanjablonski',
#  'alondrabayybee',
#  'melisentitzkovs',
#  'uhurunetwokr',
#  'uhurunetwokr',
#  'instronaut',
#  'kaylacortez02',
#  'kaylacortez02',
#  'xooceanxo',
#  'chadrickross',
#  'cscoughlin',
#  'twalkqadahulk',
#  'loyeshii',
#  'justinpenguyen',
#  'drinks',
#  'thefallenang_',
#  'gjbgjj',
#  'gjbgjj',
#  'ciamia1212',
#  'bcakeswehigh',
#  'freddylustre',
#  'avivranthing',
#  'ell_dubbbb',
#  'g_fisher33',
#  'g_fisher33',
#  'tailynwalborn',
#  'guyitsmathew',
#  'wjared4',
#  'kidmartini',
#  'kidmartini',
#  '_kevinkent_',
#  'ntumuju',
#  'm_musolf17',
#  'm_musolf17',
#  'anabeljuarez_',
#  '_bellaavida',
#  'genizh',
#  'marinavictoria',
#  'marinavictoria',
#  'queen_ericad',
#  'doherty521',
#  'webstersout',
#  'misskalelkitten',
#  'misskalelkitten',
#  'flossinic',
#  'itsavanah',
#  'denny_kruegs',
#  'msouden',
#  'dmoneybeats',
#  'dmoneybeats',
#  'ashleymariesanc',
#  'mattg103',
#  'friedlt',
#  '_jennjenny_',
#  '_jennjenny_',
#  'peelsreel',
#  '_skyyisthelimit',
#  'simplyaprillyn',
#  'simplyaprillyn',
#  'demetriaslovex',
#  'mminhas',
#  'mminhas',
#  'mminhas',
#  'amberdale_1111',
#  'passo2345',
#  'pr0mstar',
#  'mendozaemily_',
#  'side_effectzz',
#  '2buckets3',
#  'mendozaivan572',
#  'love72215',
#  'lelajamalabad',
#  'lelajamalabad',
#  'chaltontmgivee',
#  'heyhauser41',
#  'sluevanos',
#  'scottiecrippen',
#  'oooanthony',
#  'oooanthony',
#  'victoriamunoz4',
#  'velonixfifa',
#  'akm1191',
#  'ausev21',
#  'adee426',
#  'ianndelgado',
#  'peopleandthings',
#  'bienerz',
#  'loveemiliealice',
#  'williej680',
#  'alsworld_',
#  '_mayorbuck_',
#  'caiken13',
#  'coachaplin',
#  'elliwerepanther',
#  'goodwin_shanna',
#  'aidansavage1',
#  'trillvisionz',
#  'mercury_johne',
#  'dopeystyles_',
#  'cinnamonslittle',
#  'benjaminhgau',
#  'adriatic425',
#  'coreyquintal',
#  'gotoburke',
#  'skinnyemmanuel',
#  'thecartoonist2',
#  'carolinebushh',
#  'care_4_health',
#  'f_distefan0',
#  'alex_796',
#  'alex_796',
#  'wglick30',
#  'wglick30',
#  'plusbvnds',
#  'hcbeachpatrol',
#  'eclipsecaraudio',
#  'markvaughan2',
#  'darkbrony',
#  'm4r13n4_r3n33',
#  'jadefranks',
#  'johnnysuber21',
#  'up2parr',
#  'caleb_clough',
#  'caleb_clough',
#  'rrchilli',
#  'krangballs',
#  'krangballs',
#  'joannavasquez3',
#  'brandonmorocco',
#  'suavsuav912',
#  'imusicplug',
#  'joanbp',
#  'muffinmacdairmo',
#  'muffinmacdairmo',
#  'noahwg',
#  'espinosathough',
#  'lburkhardt523',
#  'ravindra_rajput',
#  'thatcoollazyguy',
#  'g21america',
#  'g21america',
#  'tailer16107686',
#  'tailer16107686',
#  'mr_t_reams',
#  'alandra_maine',
#  'haley_rigdon',
#  'haley_rigdon',
#  'ilovegarick',
#  'cameronjkrager',
#  'alwayskerry',
#  'bfernandezii',
#  'bfernandezii',
#  'brettmcdowell',
#  'daiseyfi90a04v',
#  'ashley_mccool',
#  'jb6manbl',
#  'kenchapmancny',
#  'brosleather',
#  'nohemicandle',
#  'nohemicandle',
#  'rickey64',
#  'albanybid',
#  'clarawernerx',
#  'hipsterstewie',
#  'ayyo_itsmike',
#  'badgalninii',
#  'inhal3x',
#  'bradtoberman',
#  'gnawesomething',
#  'gnawesomething',
#  'tmcfaddin77',
#  'unroastbeef',
#  'boulderiba',
#  'mississippiyoga',
#  'merlottesgrrl6',
#  'suzcoates',
#  'vic_vegaa',
#  'cheezeeheadd',
#  'jenlpaso',
#  'chrisgriffith',
#  'hoadleyca_',
#  'hoadleyca_',
#  'chrislynburge',
#  'wilsonj0230',
#  'kenziepersio',
#  'sarahkwolf',
#  'kimberlylianna',
#  'zachgirard1',
#  'wuzbrackin_',
#  'wuzbrackin_',
#  'fgcervantez',
#  'christocraig_',
#  'milkygravs',
#  'eazybrizzey',
#  'jessicaskylar1',
#  'graciebby93',
#  'brittanyamonroe',
#  'aleyvette1',
#  'aleyvette1',
#  'bitchhhh_imdope',
#  'keenan_kong',
#  'dathylian',
#  'honeyy_marie',
#  'leighbojan',
#  'julia_passanisi',
#  'mfflglobal',
#  'mfflglobal',
#  'loudpacklucy',
#  'sarax143x',
#  'sarax143x',
#  'annababe8',
#  'terencenance',
#  'exxxekutive',
#  'nihal201',
#  'bryerxdelxrey',
#  'cathh_patenaude',
#  'andru_garcia98',
#  'chasingdabieber',
#  'b_attaway',
#  'lauraholics',
#  'mathesonblake',
#  'c_nicole_d',
#  'freejohnjo',
#  'gonzalezf18',
#  'qvinnmahrtin',
#  'tristan_meagher',
#  'tristan_meagher',
#  'valentineonair',
#  'mattfiling',
#  'jsnowpro',
#  'ramajerocpromo',
#  'sincerly_kekee',
#  'lin_dai',
#  'heather0bby',
#  'youstrokei_moan',
#  'cmshaka',
#  'nexusconference',
#  'nickoliny',
#  'corinnebittner',
#  'juliel1021',
#  'ifartsparkles',
#  'berlin67berlin',
#  'novacadamatre',
#  'fkerrestj',
#  'hayleymorten',
#  'hayleymorten',
#  'jessicag_21',
#  'bgresham13',
#  'steffaniembrown',
#  'bzeindeucedeuce',
#  '360media',
#  'egranata01',
#  'twerkingtucans',
#  'ryanlschaaf',
#  'breezy613',
#  'thelilycollnsid',
#  'thelilycollnsid',
#  'thaprinceofame',
#  'ryanpkuhns',
#  'ryanpkuhns',
#  'kaylaadiane',
#  'emilyrivero',
#  'gallavichlover',
#  'justenlarson',
#  'adc9595',
#  'cjdicker',
#  'zombiexhooker',
#  'brendanbown',
#  'kimmie_davidson',
#  'thebrownmamba27',
#  'jc_docuyanan',
#  'jc_docuyanan',
#  'siouxierising',
#  'jasonking___',
#  'wehitbitches',
#  'detkatebeckett',
#  'bfarineau',
#  'laurhollander',
#  'bethosaurousrex',
#  'thatneatblog',
#  'stevetrc',
#  'cehart1',
#  'pipsyyy',
#  'ileanataly',
#  'madrigal_noe',
#  'madrigal_noe',
#  'pj_lee',
#  'kuhn112358',
#  'terileecampbell',
#  'terileecampbell',
#  'bothetrainer',
#  'kayla_britt19',
#  'padi01rafael',
#  'rypk3ma',
#  'dkiaw',
#  'dkiaw',
#  'papa_bear2006',
#  'shanna_salek',
#  'mrahrens',
#  'luke_garvey',
#  'monicabv143',
#  'eliotnafziger99',
#  'margogray48',
#  'morsonyc',
#  'outwirler',
#  '_berryyy_',
#  '_berryyy_',
#  'armydyke',
#  'armydyke',
#  'umm_plz',
#  'jedsterling',
#  'spotneruk',
#  'brainsandbronze',
#  'royalqueen_xo',
#  'xashleyulrichx',
#  'thedavegraybill',
#  'berfinzel',
#  'littlebabykeel',
#  'daisy_believe13',
#  'seaairugh',
#  'josebarrientoss',
#  'bigd91294',
#  'terrahanselmi',
#  'ajperez9',
#  'imamaclover',
#  'tommywbu_',
#  'july_mahomie',
#  'ilovethislife_',
#  'specturner',
#  'c_bass82',
#  '9ernonstop',
#  'acumenic',
#  'acumenic',
#  'harrymillard_94',
#  'dylanjadeee',
#  'felt_emily',
#  'livallyne',
#  'dr_kcbrown',
#  'nicks523',
#  'beatboxfluteguy',
#  'beatboxfluteguy',
#  'brooklynusd15',
#  'brooklynusd15',
#  'timboslice144',
#  'graftonpolice',
#  'graftonpolice',
#  'meghanmoline',
#  'meghanmoline',
#  'mahaylee1',
#  'raylortoy',
#  'authorcarnialv',
#  'kleboldwf',
#  'brusil',
#  '_itsjimmy',
#  'theproxy',
#  'kimmie____',
#  'ryanmac16',
#  'illminddtweets_',
#  'mrvachyna',
#  '_jthorn_',
#  'evanloechelt11',
#  'queeenjazzz',
#  'cat_hope88',
#  'cat_hope88',
#  'im_catastic',
#  'im_catastic',
#  'mkcallaway',
#  'ssgadvisors1',
#  'ssgadvisors1',
#  'jaysonsmith_',
#  'amyndunn',
#  'joodyjoods',
#  'drink_a_natty',
#  'sts412',
#  'hannnahroy',
#  'bdalgliesh',
#  'jordanhunley16',
#  'ladybarberbrown',
#  'vangiedarling',
#  'sigma_devil',
#  '_kyleemae',
#  'xoxogirl',
#  'lrichendollar',
#  'lrichendollar',
#  'donna_mathews01',
#  'sofarizzy',
#  '62mcfadden',
#  '62mcfadden',
#  'sundaysoccerpro',
#  'candiiibaby',
#  'skipwithmelukee',
#  'chiefgreenthumb',
#  'alexis79alexis',
#  'germantownpd',
#  'germantownpd',
#  'tjlove03',
#  'lightbriight',
#  'zacyoung97',
#  'missmonicaj6',
#  'damon_teh_wolf',
#  'damon_teh_wolf',
#  'sudeenealva',
#  'sudeenealva',
#  'biancaseyebrows',
#  'iwannabelisa2',
#  '__qveennaeee',
#  'tlohbooks',
#  'karissacramerrr',
#  'shoffvfl',
#  'oh_trizzz',
#  'stoddardke10d34',
#  '_kismettt',
#  'aubreymayne',
#  'faneigh',
#  'dereksaathoff',
#  'taylor_made901',
#  'milesofpayne',
#  'chos3non3',
#  'itspoohbro',
#  'domipops',
#  'tracilynndean',
#  'tracilynndean',
#  'johnsunununu',
#  'bambamcamtaylor',
#  'ryanepxc3',
#  '_elainers',
#  'hail___',
#  'newmie',
#  'adzwaqueen',
#  'londagodsgift',
#  'danceinspirex',
#  'dawncassidy573',
#  'jhnandrwadms',
#  'nenesharnese',
#  'asppenboyyce',
#  'vmstech24',
#  'shanastine',
#  'shanastine',
#  'supersingh001',
#  'soulbirdjade87',
#  'soulbirdjade87',
#  'moodymk',
#  'everyday_church',
#  'everyday_church',
#  'a_42_ricci',
#  'shabbades_',
#  '_qtwithabooty',
#  'cokesfin42',
#  'crushing93',
#  'smichelled17',
#  'smichelled17',
#  'neomd71',
#  'tfox1010',
#  'jaybeonthat',
#  'inikilouwho',
#  'valeriecrux',
#  'jandrsnn',
#  'songster7even',
#  'songster7even',
#  'kori_ography29',
#  'xfsista',
#  'jimjag',
#  'the_bonedoctor',
#  '_alexisreed_',
#  '_alexisreed_',
#  'morphsites',
#  'lilasadafi',
#  'kenabis_',
#  'kenabis_',
#  'heybiebzy',
#  '_juliannarose',
#  'echo_31',
#  'allisonkpark',
#  'spetras73',
#  'johnwatsonisgay',
#  'xoxo_candy_kiss',
#  'xoxo_candy_kiss',
#  'laspoxaroumeni',
#  'balieejou',
#  'lmleone14',
#  'lyndon_lazore65',
#  'promyke76_gm',
#  'assbeards',
#  'mtchstrr',
#  'pallottasitalia',
#  '__eliiiiii',
#  'sneekerphreek',
#  'sneekerphreek',
#  'mdikry13',
#  'jackie_corral',
#  'smithynufc',
#  'jtimbermusic',
#  'mahones_shadow',
#  'night91wolf',
#  'lostmsfit',
#  'el_mccabe',
#  'ispiffy_143',
#  '_souljaspence',
#  'xoxlovehim5322x',
#  'torianddean',
#  'glewis202',
#  'liamlovebug',
#  'kerrry_a',
#  'mikaylavball7',
#  'gkeyante',
#  'mommyscancer',
#  'lisashante2',
#  'reenayy',
#  'alexa_soy',
#  'karismaog_',
#  'rachnanivas',
#  'jess_ashleyx3',
#  '_itselainnne',
#  'josephperri',
#  'gorgeousladi',
#  'troparrogant',
#  'daniellemullig2',
#  'who_daaaat',
#  'who_daaaat',
#  'kiddprincemj',
#  'pondermuffin',
#  'chiciobigmeash',
#  'mtcarmelredsea',
#  'edenvortex',
#  'edenvortex',
#  'jsmack28',
#  'the_renegade_jw',
#  'megameister',
#  'hmizzell',
#  'zoeybuteraxo',
#  'jffrothman',
#  'holleigh_irene',
#  'kystevo',
#  'caseyrisner',
#  'caseyrisner',
#  'xoxo__robin',
#  'lydiagall',
#  'tallimags',
#  'dreaboss187',
#  'brighttigers',
#  'asmurraybray',
#  'simmonsleads',
#  'runnin_on_e_42',
#  'cq_zhang',
#  'paigeholliday',
#  'sally_wallyyy',
#  'coolboy_anu',
#  'felicia79373547',
#  'shakirasmith_',
#  'marcosvntonio',
#  'annereimers9236',
#  'golfmix',
#  'thejd_15',
#  'souljahselekta',
#  'fugatetanner',
#  'fugatetanner',
#  'killz_upscale',
#  'chadhartsays',
#  'psmithy101',
#  'psmithy101',
#  'rabbitrockmktg',
#  'hawkes_connor',
#  'ellyngallagher',
#  'jessicaakajess9',
#  'texaskal_el',
#  'n1ckjaye',
#  'tiahalvax',
#  'yusufshakir_',
#  'yusufshakir_',
#  'laurenfisher98',
#  'quan_dq15',
#  'quan_dq15',
#  'momaduesheikh',
#  'kayall89',
#  'christinet4real',
#  'christinet4real',
#  'milksugarcakes',
#  'bre_tr',
#  'nedicaryana',
#  'trey_mcgee',
#  'farmgirlmarymoo',
#  'rzachry54',
#  'youngcletis',
#  'jon_izaguirre',
#  'brazilianbb',
#  'racheljoelle',
#  'navoba',
#  'the_keambra',
#  'fancynancy219',
#  'oftenimprudent',
#  'mikey614global',
#  'kirsten_karbach',
#  'plushtoysadvent',
#  'plushtoysadvent',
#  'aussy5',
#  '4thfloorwalkup',
#  'shellnm',
#  'aksooooocal',
#  'emma_koss',
#  'taylorborjagang',
#  'danigullickson',
#  'muffinlady18',
#  'xoxo_mayahhh',
#  'est_12301997',
#  'beccamayyyy',
#  'alexamaria98',
#  'crystaldenellh',
#  'beats713',
#  'simplyadoll',
#  'thefakescottn',
#  'pittzprincess',
#  'jaybogarrison',
#  'imkarlalala',
#  'virtueandpearls',
#  'tshirtpreacher',
#  'gracegdmn',
#  'russgtlm',
#  'alyssathegreat6',
#  'xy1ngx',
#  'contreraz_lily',
#  'crazzero',
#  'megpalm98',
#  'keeli_garroutte',
#  'karunareigns',
#  'smilingsince96',
#  'sghquansi',
#  'mer_rygoround',
#  'mrsworththework',
#  'joedaypac',
#  'codypchristian',
#  'codypchristian',
#  'jarrodlark',
#  'mikesaint8',
#  'social___klout',
#  'nate_timmons',
#  'kmic90',
#  '51kof',
#  'dittycheria',
#  'realmikeshapiro',
#  'djnuknukysmg',
#  'djnuknukysmg',
#  'nique_nikkole',
#  'lucia_isabel',
#  'jgaz10',
#  'endureyoga1',
#  'debrahernandezz',
#  'absal95',
#  'absal95',
#  'alexstern34',
#  'endicottcollege',
#  'perslianev',
#  'catvillalobos',
#  'realjimewen',
#  'realjimewen',
#  'kelseycass',
#  'drcrosson',
#  'an_dres92',
#  'tealgale',
#  'tealgale',
#  'laced_up_left15',
#  'lynnsingerbib',
#  'chaterine_colon',
#  'keegan_warren93',
#  'fayolapippin',
#  'kitkathyela',
#  ...]

# %% [markdown]
# # Top Row

# %%
fil_train = train.loc[train['from_user'].str.lower().isin(users)]
fil_train['from_user'] = fil_train['from_user'].str.lower()
fil_train['create_time'] = pd.to_datetime(fil_train['create_time'],unit='s')

fil_train['location'] = fil_train.location.str.replace('loc_','')
fil_train = fil_train[~fil_train.term.str.contains("rt")]

fil_train = fil_train[['from_user', 'create_time', 'location', 'term', 'label']]
fil_train.columns = ['User Id', 'Time', 'Location', 'Text', 'Y']
# Out:
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fil_train.to_csv('filtered_train.tsv', sep='\t', index=False)

# %%
fil_test = test.loc[test['from_user'].str.lower().isin(users)]

# %%
fil_test['from_user'] = fil_test['from_user'].str.lower()
fil_test['create_time'] = pd.to_datetime(fil_test['create_time'],unit='s')

fil_test['location'] = fil_test.location.str.replace('loc_','')
fil_test = fil_test[~fil_test.term.str.contains("rt")]

fil_test = fil_test[['from_user', 'create_time', 'location', 'term', 'label', 'prob']]
fil_test.columns = ['User Id', 'Time', 'Location', 'Text', 'Y', 'Probability']
# Out:
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
high_score_fil_test = fil_test[fil_test.Probability > 0.75]

# %%
high_score_fil_test.to_csv('high_prob_test.tsv', sep='\t', index=False)

# %%
low_score_fil_test = fil_test[fil_test.Probability < 0.25]

# %%
low_score_fil_test.to_csv('low_prob_test.tsv', sep='\t', index=False)

# %%
low_score_fil_test.Probability.min()
# Out:
# 5.785827141432337e-10

# %%
import pandas
result_ms=pandas.to_datetime('1390968009.0',unit='s')
str(result_ms)
# Out:
# '2014-01-29 04:00:09'
